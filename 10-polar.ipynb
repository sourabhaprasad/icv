# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('sample3.webp')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(gray, 50, 150)

lines = cv2.HoughLines(edges, 1, np.pi / 180, 80)

if lines is not None:
    for rho, theta in lines[:20, 0]:
        a, b = np.cos(theta), np.sin(theta)
        x0, y0 = a * rho, b * rho
        x1, y1 = int(x0 + 1000 * (-b)), int(y0 + 1000 * a)
        x2, y2 = int(x0 - 1000 * (-b)), int(y0 - 1000 * a)

        # Draw the line
        cv2.line(img, (x1, y1), (x2, y2), (0, 255, 0), 2)

        print(f"rho = {rho:.2f}, theta = {np.degrees(theta):.2f}°")


plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('Hough Line Detection (Polar Coordinates)')
plt.axis('off')
plt.show()
# Out:
# rho = 144.00, theta = 0.00°
# rho = 81.00, theta = 90.00°
# rho = 942.00, theta = 90.00°
# rho = 360.00, theta = 90.00°
# rho = 375.00, theta = 90.00°
# rho = 362.00, theta = 90.00°
# rho = 373.00, theta = 90.00°
# rho = 679.00, theta = 90.00°
# rho = 467.00, theta = 90.00°
# rho = 465.00, theta = 90.00°
# rho = 518.00, theta = 90.00°
# rho = 520.00, theta = 90.00°
# rho = 441.00, theta = 90.00°
# rho = 624.00, theta = 90.00°
# rho = 573.00, theta = 90.00°
# rho = 257.00, theta = 90.00°
# rho = 439.00, theta = 90.00°
# rho = 245.00, theta = 90.00°
# rho = 599.00, theta = 90.00°
# rho = 597.00, theta = 90.00°
